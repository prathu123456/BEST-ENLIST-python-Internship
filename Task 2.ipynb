# %%
a = b = c = 10
print(a/10)
print(b*50)
print(c+60)
# Out:
# 1.0
# 500
# 70

# %%
a = 'ALRAE'
a = a.replace('R','G')
print(a)
# Out:
# ALGAE

# %%
a,b = 20,30.35
print(float(a))
print(int(b))
# Out:
# 20.0
# 30
