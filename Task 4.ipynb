# %%
List=['13','34','89','90']
print(List)
List.append('67')
print(List)
List.remove('13')
print(List)
a=max(List)
print(a)
b=min(List)
print(b)
# Out:
# ['13', '34', '89', '90']
# ['13', '34', '89', '90', '67']
# ['34', '89', '90', '67']
# 90
# 34

# %%
def Reverse(tuples):
    new_tup=tuples[::-1]
    return new_tup
tuples=('z','s','k','y','u','p')
print(Reverse(tuples))
# Out:
# ('p', 'u', 'y', 'k', 's', 'z')

# %%
aTuple=('123','xyz','zara','poj');
aList=list(aTuple)
print("List elements:",aList)
# Out:
# List elements: ['123', 'xyz', 'zara', 'poj']
