# %% [markdown]
# EXERCISE :

# %% [markdown]
# 1) Write a program to create a list of n integer values and do the following :
#   a) Add an item in to the list (using function),
#   b) Delete (using function),
#   c) Store the largest number from the list to a variable,
#   d) Store the smallest number from the list to a variable.

# %%
list = ["5","10","15","40","70"]
print("List :",list)
list.append("50")
print("List after adding 50 :",list)
list.remove("15")
print("List after removing 15 :",list)
a = max(list)
b = min(list)
print("Largest number a :",a)
print("Smallest number b :",b)
# Out:
# List : ['5', '10', '15', '40', '70']
# List after adding 50 : ['5', '10', '15', '40', '70', '50']
# List after removing 15 : ['5', '10', '40', '70', '50']
# Largest number a : 70
# Smallest number b : 10

# %% [markdown]
# 2) Create a tuple and print the reverse of the created tuple

# %%
Tuple_1 = ["do","run","went","is"]
print("Tuple 1 :",Tuple_1)
REV = reversed(Tuple_1)
print("Reverse of Tuple 1 :",tuple(REV))
# Out:
# Tuple 1 : ['do', 'run', 'went', 'is']
# Reverse of Tuple 1 : ('is', 'went', 'run', 'do')

# %% [markdown]
# 3) Create a tuple and convert tuple into list

# %%
aTuple = (True,28,'Tiger')
print("Tuple :",aTuple)
aList = list(aTuple)

print("Tuple converted into list :",aList)
# Out:
# Tuple : (True, 28, 'Tiger')
# Tuple converted into list : [True, 28, 'Tiger']
